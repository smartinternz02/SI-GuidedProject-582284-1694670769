# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('car_crashes')

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
sns.scatterplot(x="alcohol",y="not_distracted",data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.lineplot(x="alcohol",y="not_distracted",data=df,ci=None)
# Out:
# <ipython-input-8-46164a1eaf06>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="alcohol",y="not_distracted",data=df,ci=None)
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
sns.distplot(df["alcohol"])
# Out:
# <ipython-input-9-281d56044cde>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["alcohol"])
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
sns.distplot(df["not_distracted"])
# Out:
# <ipython-input-10-88e0b855dbfb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["not_distracted"])
# <Axes: xlabel='not_distracted', ylabel='Density'>

# %%
sns.distplot(df["speeding"])
# Out:
# <ipython-input-11-8ecb7fd34a3c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["speeding"])
# <Axes: xlabel='speeding', ylabel='Density'>

# %%
sns.relplot(x="alcohol",y="not_distracted",data=df,hue="speeding")

# %%
sns.barplot(data=df,x="alcohol",y="speeding",ci=None)
# Out:
# <ipython-input-14-74bdb265a071>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="alcohol",y="speeding",ci=None)
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
sns.barplot(data=df,x="alcohol",y="not_distracted",ci=None)
# Out:
# <ipython-input-15-c836539ef2b1>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="alcohol",y="not_distracted",ci=None)
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
sns.barplot(data=df,x="speeding",y="not_distracted",ci=None)
# Out:
# <ipython-input-16-0b4629ab94d6>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="speeding",y="not_distracted",ci=None)
# <Axes: xlabel='speeding', ylabel='not_distracted'>

# %%
sns.barplot(x="alcohol",y="not_distracted",data=df,hue="speeding")
# Out:
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
sns.barplot(x="alcohol",y="not_distracted",data=df,hue="total")
# Out:
# <Axes: xlabel='alcohol', ylabel='not_distracted'>

# %%
sns.barplot(data=df,x="speeding",y="total",ci=None)
# Out:
# <ipython-input-19-2057aad26f30>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="speeding",y="total",ci=None)
# <Axes: xlabel='speeding', ylabel='total'>

# %%
sns.barplot(data=df,x="alcohol",y="total",ci=None)
# Out:
# <ipython-input-20-eea26920b964>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,x="alcohol",y="total",ci=None)
# <Axes: xlabel='alcohol', ylabel='total'>

# %%
sns.relplot(x="alcohol",y="not_distracted",data=df,hue="total")

# %%
sns.relplot(x="alcohol",y="speeding",data=df,hue="total")

# %%
sns.distplot(df["total"])
# Out:
# <ipython-input-23-0d5ead9bfd1a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["total"])
# <Axes: xlabel='total', ylabel='Density'>

# %%
sns.countplot(x="abbrev",data=df)
# Out:
# <Axes: xlabel='abbrev', ylabel='count'>

# %%
sns.jointplot(x="alcohol",y="total",data=df)

# %%
sns.jointplot(x="speeding",y="total",data=df)

# %%
sns.jointplot(x="alcohol",y="not_distracted",data=df)

# %%
sns.boxplot(x="alcohol",y="speeding",data=df)
# Out:
# <Axes: xlabel='alcohol', ylabel='speeding'>

# %%
sns.boxplot(x="speeding",y="total",data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %%
sns.boxplot(x="speeding",y="alcohol",data=df)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-31-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %%
sns.heatmap(corr,annot=True,cmap="YlGnBu")
# Out:
# <Axes: >

# %%
sns.lineplot(x="alcohol",y="total",data=df,ci=None)
# Out:
# <ipython-input-33-10da8a41c1e4>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="alcohol",y="total",data=df,ci=None)
# <Axes: xlabel='alcohol', ylabel='total'>

# %%
sns.lineplot(x="speeding",y="not_distracted",data=df,ci=None)
# Out:
# <ipython-input-34-6d7c3bdf9c29>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="speeding",y="not_distracted",data=df,ci=None)
# <Axes: xlabel='speeding', ylabel='not_distracted'>

# %%
sns.lineplot(x="total",y="not_distracted",data=df,ci=None)
# Out:
# <ipython-input-35-ea62f8671e54>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="total",y="not_distracted",data=df,ci=None)
# <Axes: xlabel='total', ylabel='not_distracted'>
